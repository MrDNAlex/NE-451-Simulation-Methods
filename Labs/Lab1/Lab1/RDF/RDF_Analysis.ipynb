# %% [markdown]
# # Load Data from the file

# %%
import pandas
import matplotlib.pyplot as plt

def read_RDF_File (path : str):
    df = pandas.read_csv(path, skiprows=4, delim_whitespace=True, header=None)
    columns = [
    "Bin", "r",
    "g_Li-Li", "coord_Li-Li",
    "g_Li-Mn", "coord_Li-Mn",
    "g_Li-O", "coord_Li-O"
    ]
    
    df.columns = columns
    
    return df

RDF_Data_20 = read_RDF_File("Data/RDF_20.data")
RDF_Data_100 = read_RDF_File("Data/RDF_100.data")
RDF_Data_100_2 = read_RDF_File("Data/RDF_100_2.data")
RDF_Data_100_3 = read_RDF_File("Data/RDF_100_3.data")
# Out:
# /tmp/ipykernel_4038718/1173093236.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pandas.read_csv(path, skiprows=4, delim_whitespace=True, header=None)
# /tmp/ipykernel_4038718/1173093236.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pandas.read_csv(path, skiprows=4, delim_whitespace=True, header=None)
# /tmp/ipykernel_4038718/1173093236.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pandas.read_csv(path, skiprows=4, delim_whitespace=True, header=None)
# /tmp/ipykernel_4038718/1173093236.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# ...

# %%
def plot_RDF (points : int, df : pandas.DataFrame, title : str):
    # Plot g(r) for Li-Li, Li-Mn, Li-O
    plt.figure(figsize=(20, 16))

    plt.plot(df["r"][-points:], df["g_Li-Li"][-points:], label="Li-Li")
    plt.plot(df["r"][-points:], df["g_Li-Mn"][-points:], label="Li-Mn")
    plt.plot(df["r"][-points:], df["g_Li-O"][-points:], label="Li-O")

    plt.xlabel("Radius (Å)")
    plt.ylabel("Radial Distribution function - g(r)")
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_RDF(20, RDF_Data_20, "Radial Distribution Function (RDF) (T = 670K)")

# %%
plot_RDF(100, RDF_Data_100, "Radial Distribution Function (RDF) (T = 300K)")
plot_RDF(100, RDF_Data_100_2, "Radial Distribution Function (RDF) (T = 670K)")
plot_RDF(100, RDF_Data_100_3, "Radial Distribution Function (RDF) (T = 670K)")

# %% [markdown]
# # Plot the Li-Li Comparison

# %%
points = 100

# Plot g(r) for Li-Li, Li-Mn, Li-O

# Plot the 
plt.figure(figsize=(20, 16))
plt.plot(RDF_Data_100["r"][-points:], RDF_Data_100["g_Li-Li"][-points:], label="Li-Li - 670K")
plt.plot(RDF_Data_100_2["r"][-points:], RDF_Data_100_2["g_Li-Li"][-points:], label="Li-Li - 300")

plt.xlabel("r (Å)")
plt.ylabel("g(r)")
plt.title("Radial Distribution Function (RDF) Li-Li Comparison 670 - 300 K")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot the Li-Mn Comparison

# %%
plt.figure(figsize=(20, 16))
plt.plot(RDF_Data_100["r"][-points:], RDF_Data_100["g_Li-Mn"][-points:], label="Li-Mn - 670K")
plt.plot(RDF_Data_100_2["r"][-points:], RDF_Data_100_2["g_Li-Mn"][-points:], label="Li-Mn - 300")
plt.xlabel("r (Å)")
plt.ylabel("g(r)")
plt.title("Radial Distribution Function (RDF) Li-Mn Comparison 670 - 300 K")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot the Li-O Comparison

# %%
plt.figure(figsize=(20, 16))
plt.plot(RDF_Data_100["r"][-points:], RDF_Data_100["g_Li-O"][-points:], label="Li-O - 670K")
plt.plot(RDF_Data_100_2["r"][-points:], RDF_Data_100_2["g_Li-O"][-points:], label="Li-O - 300")

plt.xlabel("r (Å)")
plt.ylabel("g(r)")
plt.title("Radial Distribution Function (RDF) Li-O Comparison 670 - 300 K")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot the Full Comparison

# %%
# Full Comparison
plt.figure(figsize=(20, 16))

plt.plot(RDF_Data_100["r"][-points:], RDF_Data_100["g_Li-Li"][-points:], label="Li-Li - 670K")
plt.plot(RDF_Data_100["r"][-points:], RDF_Data_100["g_Li-Mn"][-points:], label="Li-Mn - 670K")
plt.plot(RDF_Data_100["r"][-points:], RDF_Data_100["g_Li-O"][-points:], label="Li-O - 670K")

plt.plot(RDF_Data_100_2["r"][-points:], RDF_Data_100_2["g_Li-Li"][-points:], label="Li-Li - 300")
plt.plot(RDF_Data_100_2["r"][-points:], RDF_Data_100_2["g_Li-Mn"][-points:], label="Li-Mn - 300")
plt.plot(RDF_Data_100_2["r"][-points:], RDF_Data_100_2["g_Li-O"][-points:], label="Li-O - 300")

plt.xlabel("r (Å)")
plt.ylabel("g(r)")
plt.title("Radial Distribution Function (RDF) Full Comparison Comaprison 670 - 300 K")
plt.legend()
plt.grid(True)
plt.show()
